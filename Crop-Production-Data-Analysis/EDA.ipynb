# %%
import sys
sys.path.append('C:\\Users\\Lenovo\\AppData\\Roaming\\Python\\Python312\\site-packages')

# %%
import pandas as pd

# seaborn
import seaborn as sns

# matplotlib
import matplotlib.pyplot as plt

# %%
a_data = pd.read_csv("data/clean/Agriculture_clean.csv")
a_data
# Out:
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345331                 West bengal   Purulia     Wheat       2015   Winter
# 345332                 West bengal   Purulia     Wheat       2016   Winter
# 345333                 West bengal   Purulia     Wheat       2017   Winter
# 345334                 West bengal   Purulia     Wheat       2018   Winter
# 345335                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield
# 0       2439.6      3415.0   1.40
# 1       1626.4      2277.0   1.40
# 2       4147.0      3060.0   0.74
# 3       4147.0      2660.0   0.64
# 4       4153.0      3120.0   0.75
# ...        ...         ...    ...
# 345331   855.0      1241.0   1.45
# 345332  1366.0      2415.0   1.77
# 345333  1052.0      2145.0   2.04
# 345334   833.0      2114.0   2.54
# 345335   516.0       931.0   1.80
#
# [345336 rows x 8 columns]

# %%
a_data.describe()
# Out:
#            crop_year          area    production          yield
# count  345336.000000  3.453360e+05  3.453360e+05  345336.000000
# mean     2008.887512  1.167147e+04  9.447397e+05      79.475723
# std         6.564361  4.584079e+04  2.137618e+07     916.685726
# min      1997.000000  4.000000e-03  0.000000e+00       0.000000
# 25%      2003.000000  7.400000e+01  7.700000e+01       0.560000
# 50%      2009.000000  5.320000e+02  6.810000e+02       1.020000
# 75%      2015.000000  4.112000e+03  6.940000e+03       2.520000
# max      2020.000000  8.580100e+06  1.597800e+09   43958.330000

# %% [markdown]
# # EDA on Agriculture data

# %% [markdown]
# # Plotting categoricals and numericals

# %%
sns.countplot(data = a_data, x = "state", palette="viridis")

plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14820\1629415025.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = a_data, x = "state", palette="viridis")

# %%
a_data.state.value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='state'>

# %%
a_data.district.value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='district'>

# %%
sns.countplot(data = a_data, x = "crop")

plt.xticks(rotation = 90)
plt.show()

# %%
a_data.crop.value_counts()[:10]
# Out:
# crop
# Rice                 21611
# Maize                20513
# Moong(Green Gram)    15139
# Urad                 14581
# Sesamum              13049
# Groundnut            12586
# Wheat                11220
# Rapeseed &Mustard    11034
# Sugarcane            10942
# Arhar/Tur            10885
# Name: count, dtype: int64

# %%
a_data.crop.value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='crop'>

# %%
sns.countplot(data = a_data, x = "crop_year")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.histplot(data = a_data, x = "production", bins = 10)
plt.show()

# %%
sns.histplot(data = a_data, x = "area", bins = 10)
plt.show()

# %%
# sns.displot(data = a_data, x = "area")
# plt.show()

# %%
sns.boxplot(data = a_data, x = "production")
# Out:
# <Axes: xlabel='production'>

# %%
sns.boxplot(data = a_data, x = "area")
# Out:
# <Axes: xlabel='area'>

# %%
sns.boxplot(data = a_data, x = "yield")
# Out:
# <Axes: xlabel='yield'>

# %%
# There are several oultiers in yield, area and production.

# %%
# Kerala state has highest crop production.
a_data.groupby(["state"]).agg({"production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='state'>

# %%
a_data.groupby(["crop"]).agg({"production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='crop'>

# %%
a_data.groupby(["crop_year"]).agg({"production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='crop_year'>

# %%
a_data.groupby(["season"]).agg({"production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='season'>

# %% [markdown]
# # EDA on population data

# %%
p_data = pd.read_csv("data/clean/Population_clean.csv")
p_data
# Out:
#                          state  1951_census  1961_census  1971_census  \
# 0                Uttar pradesh     60274800     70144160     83849775
# 1                  Maharashtra     32002500     39554900     50412240
# 2                        Bihar     29085900     34841490     42126800
# 3                  West bengal     26300670     34926000     44312017
# 4               Madhya pradesh     18615700     23218950     30017180
# 5                   Tamil nadu     30119680     33687100     41199170
# 6                    Rajasthan     15971130     20156540     25765810
# 7                    Karnataka     19402500     23587910     29299015
# 8                      Gujarat     16263700     20633305     26697488
# 9               Andhra pradesh     31115000     35983480     43502710
# 10                      Odisha     14646100     17549500     21944625
# 11                   Telangana            0            0            0
# 12                      Kerala     13549000     16904560     21347300
# 13                   Jharkhand      9697300     11606504     14227493
# 14                       Assam      8029100     10837700     14625157
# 15                      Punjab      9160990     11135404     13551069
# 16                     Haryana      5674400      7591190     10036430
# 17                Chhattisgarh      7457700      9154330     11637800
# 18           Jammu and kashmir      3254650      3561100      4616632
# 19                 Uttarakhand      2946900      3611200      4493800
# 20            Himachal pradesh      2386940      2812300      3460434
# 21                     Tripura       639984      1142282      1556342
# 22                   Meghalaya       606300       769990      1011699
# 23                     Manipur       578060       780340      1073509
# 24                    Nagaland       213700       369309       516110
# 25                         Goa       547000       590875       795997
# 26           Arunachal pradesh            0       337300       468885
# 27                     Mizoram       196970       266200       332190
# 28                      Sikkim       138093       162863       210205
# 29                       Delhi      1744500      2659990      4066400
# 30                  Puducherry       317407       369355       472836
# 31                  Chandigarh        24948       120480       257100
# 32  Andaman and nicobar island        31480        64160       115874
# 33      Dadra and nagar haveli        42846        58020        74880
# 34               Daman and diu        49482        37587        63000
# 35                 Lakshadweep        21000        24370        32900
#
#     1981_census  1991_census  2001_census  2011_census
# 0     105113300    132062800    166053600    199581477
# 1      62782820     78937190     96752500    112372972
# 2      52303000     64531200     82879910    103804630
# 3      54580650     68077970     80221300     91347736
# 4      38169500     48566800     60385090     72597565
# 5      48408080     55859300     62111390     72138958
# 6      34361860     44005990     56473300     68621012
# 7      37135710     44977200     52734986     61130704
# 8      34085800     41309580     50597200     60383628
# 9      53551030     66508170     75728400     49386799
# 10     26370270     31659740     36707900     41947358
# 11            0            0            0     35193978
# 12     25453680     29098523     31839000     33387677
# 13     17612000     21844550     26946070     32988134
# 14     18041250     22414320     26638600     31169272
# 15     16788920     20281971     24289130     27704236
# 16     12922122     16464600     21083900     25753081
# 17     14010110     17615600     20834530     25540196
# 18      5987389      7718700     10070300     12548926
# 19      5726550      7051600      8489100     10116752
# 20      4280818      5170877      6077453      6856509
# 21      2053058      2757205      3191880      3671032
# 22      1335819      1774778      2306540      2964007
# 23      1421290      1837900      2294480      2721756
# 24       775570      1210492      1990275      1980602
# 25      1008373      1170115      1348900      1457723
# 26       632502       865900      1098328      1382611
# 27       494440       690963       889690      1091014
# 28       316840       406000       541902       607688
# 29      6220973      9421311     13851503     16753235
# 30       604281       808117       974820      1244464
# 31       452960       642374       901080      1054686
# 32       189496       281990       356650       379944
# 33       104300       138290       220963       342853
# 34        79842       102110       158080       242911
# 35        40250        52820        61300        64429

# %%
p_data.describe()
# Out:
#         1951_census   1961_census   1971_census   1981_census   1991_census  \
# count  3.600000e+01  3.600000e+01  3.600000e+01  3.600000e+01  3.600000e+01
# mean   1.003073e+07  1.220141e+07  1.522697e+07  1.898375e+07  2.350881e+07
# std    1.357377e+07  1.609937e+07  1.966793e+07  2.442582e+07  3.033559e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.095175e+05  3.613068e+05  4.718482e+05  6.254468e+05  8.514542e+05
# 50%    3.100775e+06  3.586150e+06  4.555216e+06  6.104181e+06  8.570006e+06
# 75%    1.604427e+07  2.027573e+07  2.599873e+07  3.415482e+07  4.198368e+07
# max    6.027480e+07  7.014416e+07  8.384978e+07  1.051133e+08  1.320628e+08
#
#         2001_census   2011_census
# count  3.600000e+01  3.600000e+01
# mean   2.853056e+07  3.362585e+07
# std    3.718812e+07  4.301695e+07
# min    0.000000e+00  6.442900e+04
# 25%    1.067451e+06  1.438945e+06
# 50%    1.196090e+07  2.114672e+07
# 75%    5.113165e+07  5.213601e+07
# max    1.660536e+08  1.995815e+08

# %%
sns.barplot(data = p_data, x = "state", y = "1951_census")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = p_data, x = "state", y = "1961_census")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = p_data, x = "state", y = "1971_census")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = p_data, x = "state", y = "1981_census")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = p_data, x = "state", y = "1991_census")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = p_data, x = "state", y = "2001_census")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = p_data, x = "state", y = "2011_census")

plt.xticks(rotation = 90)
plt.show()

# %%
# Throughout the decades the population of Uttar pradesh, Maharashtra and Bihar have been on top. 
# Since they are bigger states. 
# Then among the smaller states, the population of Delhi increased compared to other small states.

# %%
p_data[p_data.state == "Delhi"].plot(kind = "bar")
# Out:
# <Axes: >

# %%
p_data[p_data.state == "Uttar pradesh"].plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# # EDA on rainfall data

# %%
r_data = pd.read_csv("data/clean/Rainfall_clean.csv")

# %%
r_data
# Out:
#                           state        district    jan   feb    mar    apr  \
# 0    Andaman and nicobar island         Nicobar  107.3  57.9   65.2  117.0
# 1    Andaman and nicobar island   South andaman   43.7  26.0   18.6   90.5
# 2    Andaman and nicobar island   N & m andaman   32.7  15.9    8.6   53.4
# 3             Arunachal pradesh           Lohit   42.2  80.8  176.4  358.5
# 4             Arunachal pradesh      East siang   33.3  79.5  105.9  216.5
# ..                          ...             ...    ...   ...    ...    ...
# 635                      Kerala   Thiruvanantha   19.3  21.1   35.5  116.7
# 636                      Kerala          Idukki   13.4  22.1   43.6  150.4
# 637                      Kerala        Kasargod    2.3   1.0    8.4   46.9
# 638                      Kerala  Pathanamthitta   19.8  45.2   73.9  184.9
# 639                      Kerala         Wayanad    4.8   8.3   17.5   83.3
#
#        may    jun     jul    aug  ...  jan+feb    mam    jjas    ond  monsoon  \
# 0    358.5  295.5   285.0  271.9  ...    165.2  540.7  1207.2  892.1  301.800
# 1    374.4  457.2   421.3  423.1  ...     69.7  483.5  1757.2  705.3  439.300
# 2    343.6  503.3   465.4  460.9  ...     48.6  405.6  1884.4  574.7  471.100
# 3    306.4  447.0   660.1  427.8  ...    123.0  841.3  1848.5  231.0  462.125
# 4    323.0  738.3   990.9  711.2  ...    112.8  645.4  3008.4  268.1  752.100
# ..     ...    ...     ...    ...  ...      ...    ...     ...    ...      ...
# 635  216.6  338.7   228.9  142.0  ...     40.4  368.8   871.3  522.7  217.825
# 636  232.6  651.6   788.9  527.3  ...     35.5  426.6  2276.2  564.2  569.050
# 637  217.6  999.6  1108.5  636.3  ...      3.3  272.9  3007.5  337.9  751.875
# 638  294.7  556.9   539.9  352.7  ...     65.0  553.5  1715.7  624.2  428.925
# 639  174.6  698.1  1110.4  592.9  ...     13.1  275.4  2632.1  332.5  658.025
#
#      autumn      winter  spring      summer  annual_mean
# 0     326.0  224.466667    57.9  180.233333   233.766667
# 1     301.2  149.266667    26.0  161.166667   251.308333
# 2     276.1  110.433333    15.9  135.200000   242.775000
# 3     167.1   35.366667    80.8  280.433333   253.650000
# 4     206.9   31.500000    79.5  215.133333   336.225000
# ..      ...         ...     ...         ...          ...
# 635   268.0   91.333333    21.1  122.933333   150.266667
# 636   343.2   78.133333    22.1  142.200000   275.208333
# 637   234.9   35.100000     1.0   90.966667   301.800000
# 638   359.4   94.866667    45.2  184.500000   246.533333
# 639   213.1   41.400000     8.3   91.800000   271.091667
#
# [640 rows x 25 columns]

# %%
r_data.groupby(["state"]).agg({"monsoon": "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='state'>

# %%
df = r_data.groupby(["state"]).agg({"monsoon": "sum",
                               "autumn": "sum",
                              "winter": "sum",
                              "spring": "sum",
                              "summer": "sum"})
df
# Out:
#                               monsoon  autumn       winter  spring  \
# state
# Andaman and nicobar island   1212.200   903.3   484.166667    99.8
# Andhra pradesh               3677.325  3187.8   619.866667   169.1
# Arunachal pradesh            7136.150  2828.3   708.433333  1492.7
# Assam                       11078.100  3684.1   468.866667   856.3
# Bihar                        9713.550  2460.4   324.733333   352.6
# Chandigarh                    211.050    31.8    25.866667    38.9
# Chhattisgarh                 5155.975  1113.2   148.100000   188.5
# Dadra and nagar haveli        579.225    38.6     3.633333     0.3
# Daman and diu                 740.900    71.1     8.933333     1.0
# Delhi                        1431.450   184.5    91.800000   146.7
# Goa                          1490.450   311.4    30.500000     0.1
# Gujarat                      5714.725   652.7   114.433333    10.2
# Haryana                      2682.775   387.0   228.666667   345.6
# Himachal pradesh             2775.300   471.7   548.233333   965.4
# Jammu and kashmir            2595.275   752.0  1111.233333  2016.2
# Jharkhand                    6563.425  1905.7   262.033333   391.7
# Karnataka                    6441.850  4300.7   575.466667    80.9
# Kerala                       7161.500  4072.7   930.166667   226.8
# Madhya pradesh              11729.950  1763.5   528.733333   457.9
# Maharashtra                  9938.000  2647.7   359.300000   121.6
# Manipur                      3859.525  1703.0   271.166667   496.1
# Meghalaya                    4644.575  1579.0   152.866667   151.8
# Mizoram                      3813.500  2068.4   274.466667   269.5
# Nagaland                     3613.100  1332.7   247.100000   304.4
# Odisha                       8598.875  3481.7   463.466667   671.1
# Puducherry                    362.025  1087.8   865.666667   101.7
# Punjab                       2510.925   434.0   306.366667   489.6
# Rajasthan                    4373.125   476.2   160.866667   155.8
# Sikkim                       1790.750   839.4   132.533333   309.2
# Tamil nadu                   2646.725  5981.7  3200.200000   448.7
# Tripura                      1497.225   706.6    87.533333   134.6
# Uttar pradesh               14859.325  3232.3   677.566667   934.2
# Uttarakhand                  3996.750   764.9   346.500000   644.7
# West bengal                  6655.100  2363.1   264.633333   362.6
#
#                                  summer
# state
# Andaman and nicobar island   476.600000
# Andhra pradesh               603.633333
# Arunachal pradesh           3949.033333
# Assam                       5336.100000
# Bihar                        993.233333
# Chandigarh                    26.033333
# Chhattisgarh                 261.466667
# Dadra and nagar haveli         2.466667
# Daman and diu                  2.966667
# Delhi                        130.500000
# Goa                           64.066667
# Gujarat                       55.933333
# Haryana                      252.000000
# Himachal pradesh             758.700000
# Jammu and kashmir           1960.866667
# Jharkhand                    648.433333
# Karnataka                   1321.033333
# Kerala                      1795.833333
# Madhya pradesh               296.033333
# Maharashtra                  383.800000
# Manipur                     1339.666667
# Meghalaya                   1670.733333
# Mizoram                     1710.533333
# Nagaland                    1505.633333
# Odisha                      1348.300000
# Puducherry                    93.100000
# Punjab                       361.500000
# Rajasthan                    195.200000
# Sikkim                       881.400000
# Tamil nadu                  1367.433333
# Tripura                      941.266667
# Uttar pradesh                733.366667
# Uttarakhand                  606.133333
# West bengal                 1419.366667

# %%
df.monsoon.max()
# Out:
# 14859.325

# %%
df.autumn.max()
# Out:
# 5981.7

# %%
df.spring.max()
# Out:
# 2016.2

# %%
df.summer.max()
# Out:
# 5336.099999999999

# %%
p_data.head()
# Out:
#             state  1951_census  1961_census  1971_census  1981_census  \
# 0   Uttar pradesh     60274800     70144160     83849775    105113300
# 1     Maharashtra     32002500     39554900     50412240     62782820
# 2           Bihar     29085900     34841490     42126800     52303000
# 3     West bengal     26300670     34926000     44312017     54580650
# 4  Madhya pradesh     18615700     23218950     30017180     38169500
#
#    1991_census  2001_census  2011_census
# 0    132062800    166053600    199581477
# 1     78937190     96752500    112372972
# 2     64531200     82879910    103804630
# 3     68077970     80221300     91347736
# 4     48566800     60385090     72597565

# %%
a_data.head()
# Out:
#                         state  district      crop  crop_year   season    area  \
# 0  Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon  2439.6
# 1  Andaman and nicobar island  Nicobars  Arecanut       2007   Winter  1626.4
# 2  Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon  4147.0
# 3  Andaman and nicobar island  Nicobars  Arecanut       2008   Summer  4147.0
# 4  Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon  4153.0
#
#    production  yield
# 0      3415.0   1.40
# 1      2277.0   1.40
# 2      3060.0   0.74
# 3      2660.0   0.64
# 4      3120.0   0.75

# %% [markdown]
# # Combining population data into agriculture data

# %%
a_p_data = a_data.copy()
a_p_data.head()
# Out:
#                         state  district      crop  crop_year   season    area  \
# 0  Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon  2439.6
# 1  Andaman and nicobar island  Nicobars  Arecanut       2007   Winter  1626.4
# 2  Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon  4147.0
# 3  Andaman and nicobar island  Nicobars  Arecanut       2008   Summer  4147.0
# 4  Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon  4153.0
#
#    production  yield
# 0      3415.0   1.40
# 1      2277.0   1.40
# 2      3060.0   0.74
# 3      2660.0   0.64
# 4      3120.0   0.75

# %%
# a_p_data = a_p_data.drop(["district"], axis = 1)
a_p_data.crop_year.value_counts()
# Out:
# crop_year
# 2019    19264
# 2018    18301
# 2017    18008
# 2016    17416
# 2015    16339
# 2013    16178
# 2011    16126
# 2014    15586
# 2009    15339
# 2012    15278
# 2008    15149
# 2010    14888
# 2007    14680
# 2006    14675
# 2003    14660
# 2002    14178
# 2004    14149
# 2005    14062
# 2000    13588
# 2001    13305
# 1999    13011
# 1998    12289
# 1997     8548
# 2020      319
# Name: count, dtype: int64

# %%
a_p_data.shape
# Out:
# (345336, 8)

# %%
a_p_data = a_p_data.drop_duplicates()

# %%
print(a_p_data.shape)
a_p_data
# Out:
# (345319, 8)
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345331                 West bengal   Purulia     Wheat       2015   Winter
# 345332                 West bengal   Purulia     Wheat       2016   Winter
# 345333                 West bengal   Purulia     Wheat       2017   Winter
# 345334                 West bengal   Purulia     Wheat       2018   Winter
# 345335                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield
# 0       2439.6      3415.0   1.40
# 1       1626.4      2277.0   1.40
# 2       4147.0      3060.0   0.74
# 3       4147.0      2660.0   0.64
# 4       4153.0      3120.0   0.75
# ...        ...         ...    ...
# 345331   855.0      1241.0   1.45
# 345332  1366.0      2415.0   1.77
# 345333  1052.0      2145.0   2.04
# 345334   833.0      2114.0   2.54
# 345335   516.0       931.0   1.80
#
# [345319 rows x 8 columns]

# %%
p_data_new = p_data.copy()
p_data_new.columns = ["state", 1951, 1961, 1971, 1981, 1991, 2001, 2011]

# %%
p_data_new.head()
# Out:
#             state      1951      1961      1971       1981       1991  \
# 0   Uttar pradesh  60274800  70144160  83849775  105113300  132062800
# 1     Maharashtra  32002500  39554900  50412240   62782820   78937190
# 2           Bihar  29085900  34841490  42126800   52303000   64531200
# 3     West bengal  26300670  34926000  44312017   54580650   68077970
# 4  Madhya pradesh  18615700  23218950  30017180   38169500   48566800
#
#         2001       2011
# 0  166053600  199581477
# 1   96752500  112372972
# 2   82879910  103804630
# 3   80221300   91347736
# 4   60385090   72597565

# %%
p_data_new = p_data_new.melt(id_vars = ["state"], value_vars = [1951, 1961, 1971, 1981, 1991, 2001, 2011])
p_data_new
# Out:
#                           state variable     value
# 0                 Uttar pradesh     1951  60274800
# 1                   Maharashtra     1951  32002500
# 2                         Bihar     1951  29085900
# 3                   West bengal     1951  26300670
# 4                Madhya pradesh     1951  18615700
# ..                          ...      ...       ...
# 247                  Chandigarh     2011   1054686
# 248  Andaman and nicobar island     2011    379944
# 249      Dadra and nagar haveli     2011    342853
# 250               Daman and diu     2011    242911
# 251                 Lakshadweep     2011     64429
#
# [252 rows x 3 columns]

# %%
# https://www.entechin.com/find-nearest-value-list-python/#?utm_content=cmp-true

def closest_value(input_value):
    
    input_list = [1951, 1961, 1971, 1981, 1991, 2001, 2011]
    
    difference = lambda input_list : abs(input_list - input_value)
 
    res = min(input_list, key=difference)
 
    return res

# %%
a_p_data["variable"] = a_p_data.crop_year.apply(closest_value)

# %%
a_p_data
# Out:
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345331                 West bengal   Purulia     Wheat       2015   Winter
# 345332                 West bengal   Purulia     Wheat       2016   Winter
# 345333                 West bengal   Purulia     Wheat       2017   Winter
# 345334                 West bengal   Purulia     Wheat       2018   Winter
# 345335                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield  variable
# 0       2439.6      3415.0   1.40      2011
# 1       1626.4      2277.0   1.40      2011
# 2       4147.0      3060.0   0.74      2011
# 3       4147.0      2660.0   0.64      2011
# 4       4153.0      3120.0   0.75      2011
# ...        ...         ...    ...       ...
# 345331   855.0      1241.0   1.45      2011
# 345332  1366.0      2415.0   1.77      2011
# 345333  1052.0      2145.0   2.04      2011
# 345334   833.0      2114.0   2.54      2011
# 345335   516.0       931.0   1.80      2011
#
# [345319 rows x 9 columns]

# %%
a_p_data["variable"].value_counts()
# Out:
# variable
# 2011    212858
# 2001    132461
# Name: count, dtype: int64

# %%
a_p_data_new = pd.merge(a_p_data, p_data_new, how = "inner", on = ["state", "variable"])
a_p_data_new
# Out:
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345140                 West bengal   Purulia     Wheat       2015   Winter
# 345141                 West bengal   Purulia     Wheat       2016   Winter
# 345142                 West bengal   Purulia     Wheat       2017   Winter
# 345143                 West bengal   Purulia     Wheat       2018   Winter
# 345144                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield variable     value
# 0       2439.6      3415.0   1.40     2011    379944
# 1       1626.4      2277.0   1.40     2011    379944
# 2       4147.0      3060.0   0.74     2011    379944
# 3       4147.0      2660.0   0.64     2011    379944
# 4       4153.0      3120.0   0.75     2011    379944
# ...        ...         ...    ...      ...       ...
# 345140   855.0      1241.0   1.45     2011  91347736
# 345141  1366.0      2415.0   1.77     2011  91347736
# 345142  1052.0      2145.0   2.04     2011  91347736
# 345143   833.0      2114.0   2.54     2011  91347736
# 345144   516.0       931.0   1.80     2011  91347736
#
# [345145 rows x 10 columns]

# %%
a_p_data_new.value.value_counts()
# Out:
# value
# 199581477    27385
# 72597565     18009
# 166053600    17396
# 61130704     17389
# 103804630    12440
#              ...
# 13851503        95
# 901080          70
# 1054686         54
# 242911          24
# 158080          18
# Name: count, Length: 69, dtype: int64

# %%
a_p_data_new = a_p_data_new.rename(columns = {"value" : "population"})

# %%
a_p_data_new = a_p_data_new.drop(["variable"], axis = 1)
a_p_data_new
# Out:
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345140                 West bengal   Purulia     Wheat       2015   Winter
# 345141                 West bengal   Purulia     Wheat       2016   Winter
# 345142                 West bengal   Purulia     Wheat       2017   Winter
# 345143                 West bengal   Purulia     Wheat       2018   Winter
# 345144                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield  population
# 0       2439.6      3415.0   1.40      379944
# 1       1626.4      2277.0   1.40      379944
# 2       4147.0      3060.0   0.74      379944
# 3       4147.0      2660.0   0.64      379944
# 4       4153.0      3120.0   0.75      379944
# ...        ...         ...    ...         ...
# 345140   855.0      1241.0   1.45    91347736
# 345141  1366.0      2415.0   1.77    91347736
# 345142  1052.0      2145.0   2.04    91347736
# 345143   833.0      2114.0   2.54    91347736
# 345144   516.0       931.0   1.80    91347736
#
# [345145 rows x 9 columns]

# %%
a_p_data_new.isna().sum()
# Out:
# state         0
# district      0
# crop          0
# crop_year     0
# season        0
# area          0
# production    0
# yield         0
# population    0
# dtype: int64

# %%
a_p_data_new.state.value_counts()
# Out:
# state
# Uttar pradesh                 44781
# Madhya pradesh                29906
# Karnataka                     27493
# Bihar                         24697
# Rajasthan                     20363
# Tamil nadu                    18507
# Assam                         18186
# Maharashtra                   17922
# Andhra pradesh                16363
# Odisha                        16153
# Chhattisgarh                  15285
# Gujarat                       14053
# West bengal                   12596
# Haryana                        8305
# Uttarakhand                    6702
# Nagaland                       5676
# Himachal pradesh               5043
# Jharkhand                      4991
# Kerala                         4870
# Telangana                      4684
# Arunachal pradesh              4345
# Meghalaya                      4322
# Jammu and kashmir              4175
# Punjab                         4142
# Manipur                        3089
# Tripura                        2557
# Mizoram                        2102
# Puducherry                     1127
# Sikkim                          876
# Andaman and nicobar island      724
# Goa                             393
# Dadra and nagar haveli          348
# Delhi                           203
# Chandigarh                      124
# Daman and diu                    42
# Name: count, dtype: int64

# %% [markdown]
# # Combining rainfall data into agriculture data

# %%
r_data.head()
# Out:
#                         state       district    jan   feb    mar    apr  \
# 0  Andaman and nicobar island        Nicobar  107.3  57.9   65.2  117.0
# 1  Andaman and nicobar island  South andaman   43.7  26.0   18.6   90.5
# 2  Andaman and nicobar island  N & m andaman   32.7  15.9    8.6   53.4
# 3           Arunachal pradesh          Lohit   42.2  80.8  176.4  358.5
# 4           Arunachal pradesh     East siang   33.3  79.5  105.9  216.5
#
#      may    jun    jul    aug  ...  jan+feb    mam    jjas    ond  monsoon  \
# 0  358.5  295.5  285.0  271.9  ...    165.2  540.7  1207.2  892.1  301.800
# 1  374.4  457.2  421.3  423.1  ...     69.7  483.5  1757.2  705.3  439.300
# 2  343.6  503.3  465.4  460.9  ...     48.6  405.6  1884.4  574.7  471.100
# 3  306.4  447.0  660.1  427.8  ...    123.0  841.3  1848.5  231.0  462.125
# 4  323.0  738.3  990.9  711.2  ...    112.8  645.4  3008.4  268.1  752.100
#
#    autumn      winter  spring      summer  annual_mean
# 0   326.0  224.466667    57.9  180.233333   233.766667
# 1   301.2  149.266667    26.0  161.166667   251.308333
# 2   276.1  110.433333    15.9  135.200000   242.775000
# 3   167.1   35.366667    80.8  280.433333   253.650000
# 4   206.9   31.500000    79.5  215.133333   336.225000
#
# [5 rows x 25 columns]

# %%
r_data.state.unique()
# Out:
# array(['Andaman and nicobar island', 'Arunachal pradesh', 'Assam',
#        'Meghalaya', 'Manipur', 'Mizoram', 'Nagaland', 'Tripura',
#        'West bengal', 'Sikkim', 'Odisha', 'Jharkhand', 'Bihar',
#        'Uttar pradesh', 'Uttarakhand', 'Haryana', 'Chandigarh', 'Delhi',
#        'Punjab', 'Himachal pradesh', 'Jammu and kashmir', 'Rajasthan',
#        'Madhya pradesh', 'Gujarat', 'Dadra and nagar haveli',
#        'Daman and diu', 'Maharashtra', 'Goa', 'Chhattisgarh ',
#        'Andhra pradesh', 'Tamil nadu', 'Puducherry', 'Karnataka',
#        'Kerala'], dtype=object)

# %%
r_data_new = r_data[["state", "district","monsoon", "autumn", "winter", "spring", "summer", "annual_mean"]]
r_data_new.head()
# Out:
#                         state       district  monsoon  autumn      winter  \
# 0  Andaman and nicobar island        Nicobar  301.800   326.0  224.466667
# 1  Andaman and nicobar island  South andaman  439.300   301.2  149.266667
# 2  Andaman and nicobar island  N & m andaman  471.100   276.1  110.433333
# 3           Arunachal pradesh          Lohit  462.125   167.1   35.366667
# 4           Arunachal pradesh     East siang  752.100   206.9   31.500000
#
#    spring      summer  annual_mean
# 0    57.9  180.233333   233.766667
# 1    26.0  161.166667   251.308333
# 2    15.9  135.200000   242.775000
# 3    80.8  280.433333   253.650000
# 4    79.5  215.133333   336.225000

# %%
a_p_data_new.season.value_counts()
# Out:
# season
# Monsoon       145328
# Winter        109046
# Whole Year     68673
# Summer         22098
# Name: count, dtype: int64

# %%
r_data_new = r_data_new.rename(columns = {"monsoon" : "Monsoon",
                                         "autumn" : "Autumn",
                                         "winter" : "Winter",
                                         "summer" : "Summer",
                                         "annual_mean" : "Whole Year"})

# %%
r_data_new = r_data_new.melt(id_vars = ["state", "district"], value_vars = ["Monsoon", "Winter", "Summer", "Whole Year"])

# %%
r_data_new = r_data_new.rename(columns = {"variable" : "season"})
r_data_new
# Out:
#                            state        district      season       value
# 0     Andaman and nicobar island         Nicobar     Monsoon  301.800000
# 1     Andaman and nicobar island   South andaman     Monsoon  439.300000
# 2     Andaman and nicobar island   N & m andaman     Monsoon  471.100000
# 3              Arunachal pradesh           Lohit     Monsoon  462.125000
# 4              Arunachal pradesh      East siang     Monsoon  752.100000
# ...                          ...             ...         ...         ...
# 2555                      Kerala   Thiruvanantha  Whole Year  150.266667
# 2556                      Kerala          Idukki  Whole Year  275.208333
# 2557                      Kerala        Kasargod  Whole Year  301.800000
# 2558                      Kerala  Pathanamthitta  Whole Year  246.533333
# 2559                      Kerala         Wayanad  Whole Year  271.091667
#
# [2560 rows x 4 columns]

# %%
a_p_data_new.shape
# Out:
# (345145, 9)

# %%
a_p_r_data = pd.merge(a_p_data_new, r_data_new, how = "left", left_on = ["state", "district", "season"], right_on = ["state", "district", "season"])

# %%
a_p_r_data
# Out:
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345140                 West bengal   Purulia     Wheat       2015   Winter
# 345141                 West bengal   Purulia     Wheat       2016   Winter
# 345142                 West bengal   Purulia     Wheat       2017   Winter
# 345143                 West bengal   Purulia     Wheat       2018   Winter
# 345144                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield  population      value
# 0       2439.6      3415.0   1.40      379944        NaN
# 1       1626.4      2277.0   1.40      379944        NaN
# 2       4147.0      3060.0   0.74      379944        NaN
# 3       4147.0      2660.0   0.64      379944        NaN
# 4       4153.0      3120.0   0.75      379944        NaN
# ...        ...         ...    ...         ...        ...
# 345140   855.0      1241.0   1.45    91347736  12.866667
# 345141  1366.0      2415.0   1.77    91347736  12.866667
# 345142  1052.0      2145.0   2.04    91347736  12.866667
# 345143   833.0      2114.0   2.54    91347736  12.866667
# 345144   516.0       931.0   1.80    91347736  12.866667
#
# [345145 rows x 10 columns]

# %%
a_p_r_data.isna().sum()
# Out:
# state              0
# district           0
# crop               0
# crop_year          0
# season             0
# area               0
# production         0
# yield              0
# population         0
# value         100885
# dtype: int64

# %%
a_p_r_data = a_p_r_data.rename(columns = {"value" : "mean_rainfall"})

# %%
a_p_r_data.mean_rainfall.mode()
# Out:
# 0    10.2
# Name: mean_rainfall, dtype: float64

# %%
a_p_r_data.mean_rainfall.mean()
# Out:
# 126.49785423319412

# %%
# Filling the Nan values with mean values

a_p_r_data.mean_rainfall = a_p_r_data.mean_rainfall.fillna(a_p_r_data.mean_rainfall.mean())

# %%
a_p_r_data.isnull().sum()
# Out:
# state            0
# district         0
# crop             0
# crop_year        0
# season           0
# area             0
# production       0
# yield            0
# population       0
# mean_rainfall    0
# dtype: int64

# %%
a_p_r_data
# Out:
#                              state  district      crop  crop_year   season  \
# 0       Andaman and nicobar island  Nicobars  Arecanut       2007  Monsoon
# 1       Andaman and nicobar island  Nicobars  Arecanut       2007   Winter
# 2       Andaman and nicobar island  Nicobars  Arecanut       2008  Monsoon
# 3       Andaman and nicobar island  Nicobars  Arecanut       2008   Summer
# 4       Andaman and nicobar island  Nicobars  Arecanut       2009  Monsoon
# ...                            ...       ...       ...        ...      ...
# 345140                 West bengal   Purulia     Wheat       2015   Winter
# 345141                 West bengal   Purulia     Wheat       2016   Winter
# 345142                 West bengal   Purulia     Wheat       2017   Winter
# 345143                 West bengal   Purulia     Wheat       2018   Winter
# 345144                 West bengal   Purulia     Wheat       2019   Winter
#
#           area  production  yield  population  mean_rainfall
# 0       2439.6      3415.0   1.40      379944     126.497854
# 1       1626.4      2277.0   1.40      379944     126.497854
# 2       4147.0      3060.0   0.74      379944     126.497854
# 3       4147.0      2660.0   0.64      379944     126.497854
# 4       4153.0      3120.0   0.75      379944     126.497854
# ...        ...         ...    ...         ...            ...
# 345140   855.0      1241.0   1.45    91347736      12.866667
# 345141  1366.0      2415.0   1.77    91347736      12.866667
# 345142  1052.0      2145.0   2.04    91347736      12.866667
# 345143   833.0      2114.0   2.54    91347736      12.866667
# 345144   516.0       931.0   1.80    91347736      12.866667
#
# [345145 rows x 10 columns]

# %%
# There are several district which are low in count. Hence categorizing them under 'Other'

district_df = pd.DataFrame(data = a_p_r_data.district.value_counts()).reset_index()
district_df.columns = ["name" , "count"]

display(district_df.dtypes)

names = []

for i in district_df.index:
    
    if district_df["count"][i] < 100:
        
        names.append(district_df["name"][i])

    
names
# Out:
# name     object
# count     int64
# dtype: object
# ['Suryapet',
#  'Palghar',
#  'Rajanna',
#  'Kupwara',
#  'Hanumakonda',
#  'Jagitial',
#  'Peddapalli',
#  'Jhargram',
#  'Ganderbal',
#  'Fazilka',
#  'Longding',
#  'Paschim bardhaman',
#  'Kra daadi',
#  'Shopian',
#  'Pathankot',
#  'Medchal malkajgiri',
#  'Leh ladakh',
#  'Ramban',
#  'Narayanapet',
#  'Charki dadri',
#  'Kalimpong',
#  'Lower siang',
#  'Mulugu',
#  'Kamle',
#  'Gaurella-pendra-marwahi',
#  'Kargil',
#  'Leparada',
#  'Daman',
#  'Diu',
#  'Pakke kessang',
#  'Shi yomi',
#  'Chennai',
#  'Hyderabad',
#  'Niwari',
#  'Tirupathur',
#  'Chengalpattu',
#  'Tenkasi',
#  'Kallakurichi',
#  'Ranipet',
#  'Mumbai suburban',
#  'Biswanath',
#  'Hojai',
#  'Majuli',
#  'West karbi anglong',
#  'Charaideo',
#  'Mumbai',
#  'South salmara mancachar']

# %%
a_p_r_data.district = a_p_r_data.district.apply(lambda x: 'other' if x in names else x)

a_p_r_data.district.value_counts()
# Out:
# district
# other          1997
# Bilaspur       1244
# Belagavi       1197
# Tumakuru       1175
# Aurangabad     1164
#                ...
# Mancherial      109
# Barnala         108
# Jayashankar     103
# Namsai          103
# Siang           101
# Name: count, Length: 661, dtype: int64

# %% [markdown]
# # Importing Agriculture + Population + Rainfall data into .csv

# %%
a_p_r_data.to_csv("data/clean/Agriculture_Population_Rainfall.csv", index = False)

# %%
a_p_r_data[a_p_r_data.crop == "Rice"].season.value_counts()
# Out:
# season
# Monsoon       12930
# Winter         4502
# Summer         4105
# Whole Year       74
# Name: count, dtype: int64

# %% [markdown]
# # Hypothesis Testing

# %%
# H0: The sum of Crop production is < the sum of population for year = 1997 - 2011. 
# H1: The sum of Crop production is > the sum of population for year = 1997 - 2011.

import scipy.stats as st

population = p_data_new[(p_data_new.variable == 1991) | (p_data_new.variable == 2011)]["value"]
production = a_data[(a_data.crop_year == 1991) | (a_data.crop_year == 2011)]["production"]

st.ttest_ind(a_p_r_data.population, a_p_r_data.production, equal_var=False)
# Out:
# TtestResult(statistic=707.3796963810536, pvalue=0.0, df=453515.46955207834)

# %%
# We reject the null hypothesis because p-val is 0 which is less than 0.05.
# As the statistics is positive which means that sum(population) is greater than sum(production)

# %%
p_data_new[(p_data_new.variable == 1991) | (p_data_new.variable == 2011)]["value"].sum()
# Out:
# 2056847601

# %%
print(population.mean())
print(production.mean())
# Out:
# 28567327.791666668
# 1202925.0894828227

# %%
28567327/ 1202925
# Out:
# 23.748219548184633

# %%
# H0: The sum of Crop production is < the sum of population for year = 2011. 
# H1: The sum of Crop production is > the sum of population for year = 2011.

population1 = p_data_new[p_data_new.variable == 2011]["value"]
production1 = a_data[a_data.crop_year == 2011]["production"]

st.ttest_ind(population1, production1, equal_var=False)
# Out:
# TtestResult(statistic=4.5205372849285546, pvalue=6.74430659507501e-05, df=35.05605866485445)

# %%
# We reject the null hypothesis because p-val is 0 which is less than 0.05.

# %%
p_data_new[p_data_new.variable == 2011]["value"].sum()
# Out:
# 1210530555

# %%
a_data[a_data.crop_year == 2011]["production"].sum()
# Out:
# 19398369993.0

# %%
19398369993/1210530555
# Out:
# 16.02468431125227
